# %% [markdown]
# <a href="https://colab.research.google.com/github/Prakash-sk26/cie/blob/main/ccie4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas  as pd

df=pd.read_csv("/content/diabetes_prediction_dataset.csv")
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
target = df["diabetes"]
train = df.drop("diabetes", axis=1)

print(train.head())
print(target.head())
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level
# 0          6.6                  140
# 1          6.6                   80
# 2          5.7                  158
# 3          5.0                  155
# 4          4.8                  155
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: diabetes, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 21097  80.0             0              0  39.62          5.0
# 37131  40.0             0              0  27.32          6.6
# 29220  33.0             0              0  32.28          5.0
# 69734  30.0             0              0  27.32          5.0
# 50281  54.0             0              0  26.60          3.5
# ...     ...           ...            ...    ...          ...
# 25754  49.0             0              0  23.53          6.2
# 59463  47.0             0              0  27.32          5.0
# 63814  46.0             0              0  24.48          7.0
# 20923  80.0             0              0  30.52          6.5
# 92051  65.0             0              0  27.32          5.0
#
#        blood_glucose_level
# 21097                   85
# 37131                  158
# 29220                   80
# 69734                  140
# 50281                  159
# ...                    ...
# 25754                  140
# ...

# %%
x_test
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 24237  28.0             0              0  25.09          4.8
# 38222  28.0             0              0  25.08          5.0
# 97412  80.0             0              0  38.18          5.7
# 44770  57.0             1              0  33.49          7.5
# 24420  12.0             0              0  31.11          4.8
# ...     ...           ...            ...    ...          ...
# 7329   68.0             0              0  28.64          5.7
# 92709  34.0             0              0  37.50          3.5
# 44987  67.0             0              0  30.15          3.5
# 83444  39.0             0              0  32.84          6.5
# 65477  65.0             0              0  27.32          5.8
#
#        blood_glucose_level
# 24237                  100
# 38222                  130
# 97412                  280
# 44770                  300
# 24420                  200
# ...                    ...
# 7329                   200
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
import xgboost as Xgb
from sklearn.metrics import mean_squared_error

model_1 = RandomForestRegressor()
model_2 = LinearRegression()
model_3 = Xgb.XGBRegressor()

model_1.fit(x_train, y_train)
model_2.fit(x_train, y_train)
model_3.fit(x_train, y_train)


pred_1 = model_1.predict(x_test)
pred_2 = model_2.predict(x_test)
pred_3 = model_3.predict(x_test)

final_pred = (pred_1 + pred_2 + pred_3) / 3.0

mse = mean_squared_error(y_test, final_pred)
mse
# Out:
# 0.02701951155956592
