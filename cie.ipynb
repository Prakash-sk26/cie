# %% [markdown]
# <a href="https://colab.research.google.com/github/Prakash-sk26/cie/blob/main/cie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("mtcars.csv")
#df.head()
x=df['wt']
y=df['mpg']
plt.scatter(x,y)
plt.title("Relationship between weight and mpg")
plt.xlabel("Weight")
plt.ylabel("Miles Per Gallon")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df =pd.read_csv("mtcars.csv")
auto_count = (df['am'] == 0).sum()
manual_count = (df['am'] == 1).sum()
labels = ['Automatic', 'Manual']
counts = [auto_count, manual_count]
plt.bar(labels, counts,)
plt.title("Frequency distribution ")
plt.xlabel(" Type")
plt.ylabel("Number of Cars")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("mtcars.csv")
plt.boxplot(df['mpg'])
plt.title("Distribution of MPG")
plt.xlabel("MPG")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("mtcars.csv")
import pandas as pd
import matplotlib.pyplot as plt
df =pd.read_csv("mtcars.csv")
auto_count = (df['am'] == 0).sum()
manual_count = (df['am'] == 1).sum()
labels = ['Automatic', 'Manual']
counts = [auto_count, manual_count]
plt.bar(labels, counts,)
plt.title("Frequency distribution ")
plt.xlabel(" Type")
plt.ylabel("Number of Cars")
plt.grid(True)
plt.show()
